# %% [markdown]
# # 비골절, 골절 Classifier

# %% [markdown]
# ## colab 에서 진행할 경우 (이외 건너뛰어도 무방)
# - 드라이브 마운트 필요

# %%
# to find the directory you're in ,
# !ls
#if you wanna go into a folder (say samplefolder)
# %cd /content/drive/My Drive
# Out:
# drive  sample_data
# /content/drive/My Drive

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\user'

# %%
# !unzip whole.zip -d whole
# !unzip resize_reverse_crop.zip -d resize_reverse_crop
# !unzip resize_reverse_crop_128.zip -d resize_reverse_crop_128

# %% [markdown]
# ## Load module

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
from __future__ import print_function, division

import keras
from keras import optimizers, initializers, regularizers, metrics
from keras.layers import Input, Dense, Flatten, Dropout
from keras.layers import BatchNormalization, Activation, MaxPooling2D
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.convolutional import Conv2D
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Model, load_model
from keras.optimizers import RMSprop, Adam
# from keras.models import Sequential

from os import makedirs
from os import listdir

from shutil import copyfile
from random import seed
from random import random

from matplotlib.image import imread

from PIL import Image

from sklearn.model_selection import train_test_split
from keras.utils import np_utils


# from functools import partial

import random
import keras.backend as K
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
import glob
import os
import cv2
# import keras.backend.tensorflow_backend as K
# Out:
# Using TensorFlow backend.

# %%
from numpy.random import seed
# np.random.seed(seed)
seed(1)
# from tensorflow import set_random_seed
# set_random_seed(2)

# %% [markdown]
# ## Source Data 확인
# /content/drive/My Drive/resize_reverse_crop/Normal_resize_reverse_crop_128\
# /content/drive/My Drive/resize_reverse_crop/fracture_resize_reverse_crop_128\
#
# /content/drive/My Drive/resize_reverse_crop/Normal_resize_reverse_crop\
# /content/drive/My Drive/resize_reverse_crop/fracture_resize_reverse_crop\
#
# /content/drive/My Drive/whole/x-ray/Normal_resize_reverse_crop\
# /content/drive/My Drive/whole/x-ray/fracture_resize_reverse_crop

# %%
path_normal ='./resize_reverse_crop_128/Normal_resize_reverse_crop' #20200515
path_fracture = './resize_reverse_crop_128/fracture_resize_reverse_crop' #20200515

normal_image_path_names = []
fracture_image_path_names = []

# Get Images in folders
for file_n in glob.glob(path_normal + '/*.jpg'):
  normal_image_path_names.append(file_n)

for file_f in glob.glob(path_fracture + '/*.jpg'):
  fracture_image_path_names.append(file_f)

# Check if training data looks all right

fig, axs = plt.subplots(2, 10, figsize=(15, 5))
for i in range(10) :
  img_normal = imread(normal_image_path_names[i])
  img_fracture = imread(fracture_image_path_names[i])
  fig.suptitle('Normal and Fractured', fontsize=14)
  axs[0, i].set_axis_off()
  axs[0, i].set_title('Normal{}'.format(i+1))
  axs[0, i].imshow(img_normal, cmap='gray')
  axs[1, i].set_axis_off()
  axs[1, i].set_title('Fracture{}'.format(i+1))
  axs[1, i].imshow(img_fracture, cmap='gray')

# %%
print(img_normal.shape)
print(img_fracture.shape)
# Out:
# (128, 128, 3)
# (128, 128, 3)

# %%
print(len(normal_image_path_names))
print(len(fracture_image_path_names))
# Out:
# 698
# 1204

# %% [markdown]
# ## ImageDataGenerator

# %%
# images.shape = (None, 224, 244). value = 0~225
def equalize_images(images):
    return np.array([cv2.equalizeHist(image) for image in images])
    
    
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

def generate_images_for_data_augmentation(original_path, output_path, prefix, max_gen_count):
    create_output_path(output_path)
    
    file_list = os.listdir(original_path)
    
    datagen = ImageDataGenerator(
            rotation_range=10,
            width_shift_range=0.01,
            height_shift_range=0.01,
#            shear_range=0.2,
            zoom_range=0.1,
            horizontal_flip=True,
            fill_mode="nearest")
    
    for filename in file_list:
        # copy
        shutil.copyfile(original_path + "/" + filename, output_path + "/" + filename)
        
        # generates
        img = load_img(original_path + "/" + filename)  # this is a PIL image
        
        img_data = img_to_array(img) # this is a Numpy array
        img_data = img_data.reshape((1,) + img_data.shape)  # this is a Numpy array 

        # the .flow() command below generates batches of randomly transformed images
        # and saves the results to the `preview/` directory
        generated_count = 0
        
        for batch in datagen.flow(img_data, batch_size = 1,
                                  save_to_dir=output_path, save_prefix=prefix, save_format="jpg"):
            generated_count += 1

            if generated_count > max_gen_count:
                break  # otherwise the generator would loop indefinitely

# %% [markdown]
# ## Train set, Test set 디렉토리 분류
# ###  이미 디렉토리 안에 파일이 생성되어 있는 경우 지나가도 됨
#
#  classifier\
#    ├── test\
#    │   ├── fracture\
#    │   └── normal\
#    └── train\
#   ----      ├── fracture\
#   ----      └── normal
#
#
#
# Ref:\
# https://machinelearningmastery.com/how-to-develop-a-convolutional-neural-network-to-classify-photos-of-dogs-and-cats/

# %%
# organize dataset into a useful structure

# from os import makedirs
# from os import listdir
# from shutil import copyfile
# from random import seed
# from random import random

## Step1
# create directories
dataset_home = './resize_reverse_crop_128/classifier/' #20200515
subdirs = ['images/train/', 'images/test/']
labeldirs = ['fracture/', 'normal/']

for subdir in subdirs:
    for labeldir in labeldirs:
        newdir = dataset_home + subdir + labeldir
        makedirs(newdir, exist_ok=True)
print('== Step1 is done ==')


## Step2
# seed random number generator
seed(1)

# define ratio of pictures to use for validation
val_ratio = 0.2
# val_ratio = 0.3

# copy training dataset images into subdirectories

path_normal = './resize_reverse_crop_128/Normal_resize_reverse_crop' #20200515
path_fracture = './resize_reverse_crop_128/fracture_resize_reverse_crop' #20200515


src_path = [path_fracture, path_normal]
for path in src_path:
    for file in listdir(path):
        src = path + '/' + file # './resize_reverse_crop_128/Normal_resize_reverse_crop/*.jpg'
        lab_dir = path.split('/')[-1].split('_')[0].lower() # fracture, normal
        if random.random() > val_ratio:
            subdir = 'images/train/'
            dst = dataset_home + subdir + lab_dir + '/'  + file # '.classifier/images/클래스(fracture, normal)'
            copyfile(src, dst)
        else:
            subdir = 'images/test/'
            dst = dataset_home + subdir + lab_dir + '/'  + file # '.classifier/images/클래스(fracture, normal)'
            copyfile(src, dst)
print('== Step2 is done ==')
# Out:
# == Step1 is done ==
# == Step2 is done ==

# %% [markdown]
# ## X_train, X_test, Y_train, Y_test 마련

# %% [markdown]
# Ref:\
# https://github.com/lsjsj92/keras_basic/blob/master/6.%20predict_binary_img_with_CNN.ipynb

# %%
# from PIL import Image
# import os, glob, sys, numpy as np
# from os import makedirs
# from sklearn.model_selection import train_test_split
# from keras.utils import np_utils

img_dir = './resize_reverse_crop_128/classifier/images/train' #20200515
# categories = list(class_names)
categories = ['normal', 'fracture']
np_classes = len(categories)

img_w = 128 #20200515
img_h = 128 #20200515
# channel = 3
channel = 1 #20200515

pixel = img_w * img_h * channel

X = []
y = []

for idx, category in enumerate(categories):
    img_dir_detail = img_dir + '/' + category
    files = glob.glob(img_dir_detail + '/*.jpg')
    
    for i, f in enumerate(files):
        try:
            img = Image.open(f).convert('L') #20200515
            # img = img.convert('RGB')
            img = img.resize((img_w, img_h))
            data = np.asarray(img)
            # print(data.shape)
            X.append(data)
            y.append(idx)
            if i % 300 == 0:
                print(category, ":", f)
        except:
            print(category, str(i), 'Error')

X = np.array(X)
Y = np.array(y)

##20200518
shuffled_train_index = np.random.permutation(X.shape[0])
X = X[shuffled_train_index,:,:]
Y = Y[shuffled_train_index]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.1)

xy = (X_train, X_test, Y_train, Y_test)
# Out:
# normal : ./resize_reverse_crop_128/classifier/images/train/normal\1035l.jpg
# normal : ./resize_reverse_crop_128/classifier/images/train/normal\1641l.jpg
# fracture : ./resize_reverse_crop_128/classifier/images/train/fracture\100l.jpg
# fracture : ./resize_reverse_crop_128/classifier/images/train/fracture\1272l.jpg
# fracture : ./resize_reverse_crop_128/classifier/images/train/fracture\261l.jpg
# fracture : ./resize_reverse_crop_128/classifier/images/train/fracture\482l.jpg

# %%
# Check X_train data by plotting

# import random
# import matplotlib.pyplot as plt
# from matplotlib.image import imread

ix = random.randint(1, X_train.shape[0])
plt.imshow(X_train[ix])
if Y_train[ix] == 1:
  plt.title('normal')
elif Y_train[ix] == 0:
  plt.title('fracture')
plt.show()

# %% [markdown]
# ### 나눈 Train and Test set을 numpy data로 저장

# %%
numpy_dir = './resize_reverse_crop_128/classifier/numpy_data' #20200515
numpy_data = './resize_reverse_crop_128/classifier/numpy_data/binary_image_data.npy' #20200515

makedirs(numpy_dir, exist_ok=True)
np.save(numpy_data, xy)

# %% [markdown]
# ## Classifier model

# %%
# from keras.models import Sequential
# from keras.optimizers import RMSprop
# from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
# from keras.callbacks import EarlyStopping, ModelCheckpoint
# from matplotlib.image import imread
# import matplotlib.pyplot as plt
# import keras.backend.tensorflow_backend as K
# import random

# %% [markdown]
# ### loss 0.39 acc 0.87

# %%
# loss 0.39 acc 0.87

def classifier_model(img_size, channels):
    inputs = Input(shape=(img_size, img_size, channels))
    depth = 8

    conv0 = Conv2D(depth*1, (3,3), padding='same')(inputs)
    conv0 = LeakyReLU(0.2)(conv0)
    bat0 = BatchNormalization()(conv0)
    # drop0 = Dropout(0.1)(bat0)
    drop0 = Dropout(0.1)(bat0)
    # conv0 = Conv2D(depth, (3,3), padding='same')(bat0)
    # conv0 = LeakyReLU(0.2)(conv0)
    # bat0 = BatchNormalization()(conv0)
    pool0 = MaxPooling2D(pool_size=(2,2))(drop0)
    drop0 = Dropout(0.1)(pool0)

    conv1 = Conv2D(depth*2, (3,3), padding='same')(drop0)
    conv1 = LeakyReLU(0.2)(conv1)
    bat1 = BatchNormalization()(conv1)
    drop1 = Dropout(0.1)(bat1)
    # conv1 = Conv2D(depth*2, (3,3), padding='same')(bat1)
    # conv1 = LeakyReLU(0.2)(conv1)
    # bat1 = BatchNormalization()(conv1)
    pool1 = MaxPooling2D(pool_size=(2,2))(drop1)
    drop1 = Dropout(0.1)(pool1)

    conv2 = Conv2D(depth*4, (3,3), padding='same')(drop1)
    conv2 = LeakyReLU(0.2)(conv2)
    bat2 = BatchNormalization()(conv2)
    drop2 = Dropout(0.1)(bat2)
    # conv2 = Conv2D(depth*4, (5,5), padding='same')(bat2)
    # conv2 = LeakyReLU(0.2)(conv2)
    # bat2 = BatchNormalization()(conv2)
    pool2 = MaxPooling2D(pool_size=(2,2))(drop2)
    drop2 = Dropout(0.1)(pool2)

    conv3 = Conv2D(depth*8, (3,3), padding='same')(drop2)
    conv3 = LeakyReLU(0.2)(conv3)
    bat3 = BatchNormalization()(conv3)
    drop3 = Dropout(0.5)(bat3)
    # conv3 = Conv2D(depth*8, (3,3), padding='same')(bat3)
    # conv3 = LeakyReLU(0.2)(conv3)
    # bat3 = BatchNormalization()(conv3)
    pool3 = MaxPooling2D(pool_size=(2,2))(drop3)
    drop3 = Dropout(0.1)(pool3)

    conv4 = Conv2D(depth*16, (3,3), padding='same')(drop3)
    conv4 = LeakyReLU(0.2)(conv4)
    bat4 = BatchNormalization()(conv4)
    drop4 = Dropout(0.1)(bat4)
    # conv4 = Conv2D(depth*16, (3,3), padding='same')(bat4)
    # conv4 = LeakyReLU(0.2)(conv4)
    # bat4 = BatchNormalization()(conv4)
    pool4 = MaxPooling2D(pool_size=(2,2))(drop4)
    drop4 = Dropout(0.1)(pool4)

    conv5 = Conv2D(depth*32, (3,3), padding='same')(drop4)
    conv5 = LeakyReLU(0.2)(conv5)
    bat5 = BatchNormalization()(conv5)
    drop5 = Dropout(0.1)(bat5)
    # conv5 = Conv2D(depth*32, (3,3))(drop5)
    # conv5 = LeakyReLU(0.2)(conv5)
    # bat5 = BatchNormalization()(conv5)
    pool5 = MaxPooling2D(pool_size=(2,2))(drop5)
    drop5 = Dropout(0.1)(pool5)

    conv6 = Conv2D(depth*64, (3,3), padding='same')(drop5)
    conv6 = LeakyReLU(0.2)(conv6)
    bat6 = BatchNormalization()(conv6)
    drop6 = Dropout(0.25)(bat6)
    # drop6 = Dropout(0.5)(bat6)
    # conv6 = Conv2D(depth*64, (3,3))(drop5)
    # conv6 = LeakyReLU(0.2)(conv6)
    # bat6 = BatchNormalization()(conv6)
    pool6 = MaxPooling2D(pool_size=(2,2))(drop6)
    drop6 = Dropout(0.25)(pool6)
    # drop6 = Dropout(0.5)(pool6)

    conv7 = Conv2D(depth*128, (3,3), padding='same')(drop6)
    conv7 = LeakyReLU(0.2)(conv7)
    bat7 = BatchNormalization()(conv7)
    drop7 = Dropout(0.25)(bat7) 
    # drop7 = Dropout(0.5)(bat7)

    fc = Flatten()(drop7)
    fc = Dense(depth*128, kernel_regularizer=regularizers.l2(1e-4))(fc)
    fc = LeakyReLU(0.2)(fc)
    fc = Dropout(0.5)(fc)
    fc = Dense(1)(fc)
    outputs = Activation('sigmoid')(fc)

    model = Model(inputs=[inputs], outputs=[outputs])
    model.summary()

    return model

# %% [markdown]
# ### unet_상위모델

# %%
def classifier_model():

    inputs = Input((default_crop_rect_height, default_crop_rect_width, 1))

    # conv1 = Conv2D(32, (3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(1e-3))(inputs)
    conv1 = Conv2D(32, (3, 3), activation='elu', padding='same')(inputs)
    conv1 = BatchNormalization()(conv1)
    conv1 = Conv2D(32, (3, 3), activation='elu', padding='same')(conv1)
    conv1 = BatchNormalization()(conv1)
    conv1 = Conv2D(32, (3, 3), activation='elu', padding='same')(conv1)
    conv1 = BatchNormalization()(conv1)
    conv1 = Conv2D(32, (3, 3), activation='elu', padding='same')(conv1)
    conv1 = BatchNormalization()(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    pool1 = Dropout(0.25)(pool1)

    # conv2 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(1e-3))(pool1)
    conv2 = Conv2D(64, (3, 3), activation='elu', padding='same')(pool1)
    conv2 = BatchNormalization()(conv2)
    conv2 = Conv2D(64, (3, 3), activation='elu', padding='same')(conv2)
    conv2 = BatchNormalization()(conv2)
    conv2 = Conv2D(64, (3, 3), activation='elu', padding='same')(conv2)
    conv2 = BatchNormalization()(conv2)
    conv2 = Conv2D(64, (3, 3), activation='elu', padding='same')(conv2)
    conv2 = BatchNormalization()(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    pool2 = Dropout(0.25)(pool2)

    ##
    # conv3 = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(1e-3))(pool2)
    conv3 = Conv2D(128, (3, 3), activation='elu', padding='same')(pool2)
    conv3 = BatchNormalization()(conv3)
    conv3 = Conv2D(128, (3, 3), activation='elu', padding='same')(conv3)
    conv3 = BatchNormalization()(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    pool3 = Dropout(0.25)(pool3)

    ##
    conv4 = Conv2D(256, (3, 3), activation='elu', padding='same')(pool3)
    conv4 = BatchNormalization()(conv4)
    conv4 = Conv2D(256, (3, 3), activation='elu', padding='same')(conv4)
    conv4 = BatchNormalization()(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)
    pool4 = Dropout(0.25)(pool4)

    # conv5 = Conv2D(512, (3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(1e-3))(pool3)

    conv5 = Conv2D(512, (3, 3), activation='elu', padding='same')(pool4)

    # conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool2)

    # conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = BatchNormalization()(conv5)
    conv5 = Conv2D(512, (3, 3), activation='elu', padding='same')(conv5)
    conv5 = BatchNormalization()(conv5)

    pool5 = MaxPooling2D(pool_size=(2, 2))(conv5)
    pool5 = Dropout(0.25)(pool5)
    d_conv_output = pool5


    dense1 = Flatten()(d_conv_output)
    dense2 = Dense(512, activation="elu", kernel_regularizer=regularizers.l2(1e-3))(dense1)
    dense2 = BatchNormalization()(dense2)
    dense2 = Dropout(0.5)(dense2)
    ##
    dense3 = Dense(128, activation="elu", kernel_regularizer=regularizers.l2(1e-3))(dense1)
    dense3 = BatchNormalization()(dense3)
    dense3 = Dropout(0.5)(dense3)
    c_outputs = Dense(2, activation="softmax")(dense3)

    c_model = Model([inputs], [c_outputs])
    c_model.summary()

    return  c_model

# %% [markdown]
# ### take2 (elu) (softmax)

# %%
def classifier_model():

    inputs = Input((default_crop_rect_height, default_crop_rect_width, 1))

    # conv1 = Conv2D(32, (3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(1e-3))(inputs)
    conv1 = Conv2D(32, (3, 3), activation='elu', padding='same')(inputs)
    conv1 = BatchNormalization()(conv1)
    conv1 = Conv2D(32, (3, 3), activation='elu', padding='same')(conv1)
    conv1 = BatchNormalization()(conv1)
    conv1 = Conv2D(32, (3, 3), activation='elu', padding='same')(conv1)
    conv1 = BatchNormalization()(conv1)
    #conv1 = Conv2D(32, (3, 3), activation='elu', padding='same')(conv1)
    #conv1 = BatchNormalization()(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    # pool1 = Dropout(0.9)(pool1) ##20200518
    pool1 = Dropout(0.25)(pool1)

    # conv2 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(1e-3))(pool1)
    conv2 = Conv2D(64, (3, 3), activation='elu', padding='same')(pool1)
    conv2 = BatchNormalization()(conv2)
    conv2 = Conv2D(64, (3, 3), activation='elu', padding='same')(conv2)
    conv2 = BatchNormalization()(conv2)
    conv2 = Conv2D(64, (3, 3), activation='elu', padding='same')(conv2)
    conv2 = BatchNormalization()(conv2)
    #conv2 = Conv2D(64, (3, 3), activation='elu', padding='same')(conv2)
    #conv2 = BatchNormalization()(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    pool2 = Dropout(0.25)(pool2)
    #pool2 = Dropout(0.5)(pool2) ##20200518

    ##
    # conv3 = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(1e-3))(pool2)
    conv3 = Conv2D(128, (3, 3), activation='elu', padding='same')(pool2)
    conv3 = BatchNormalization()(conv3)
    conv3 = Conv2D(128, (3, 3), activation='elu', padding='same')(conv3)
    conv3 = BatchNormalization()(conv3)
    conv3 = Conv2D(128, (3, 3), activation='elu', padding='same')(conv3)
    conv3 = BatchNormalization()(conv3)
    #conv3 = Conv2D(128, (3, 3), activation='elu', padding='same')(conv3)
    #conv3 = BatchNormalization()(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    pool3 = Dropout(0.25)(pool3)
    # pool3 = Dropout(0.75)(pool3) ##20200518

    ##
    conv4 = Conv2D(256, (3, 3), activation='elu', padding='same')(pool3)
    conv4 = BatchNormalization()(conv4)
    conv4 = Conv2D(256, (3, 3), activation='elu', padding='same')(conv4)
    conv4 = BatchNormalization()(conv4)
    conv4 = Conv2D(256, (3, 3), activation='elu', padding='same')(conv4)
    conv4 = BatchNormalization()(conv4)
    #conv4 = Conv2D(256, (3, 3), activation='elu', padding='same')(conv4)
    #conv4 = BatchNormalization()(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)
    pool4 = Dropout(0.25)(pool4)
    #pool4 = Dropout(0.5)(pool4) ##20200518


    conv5 = Conv2D(512, (3, 3), activation='elu', padding='same')(pool4)

    # conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool2)

    # conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = BatchNormalization()(conv5)
    conv5 = Conv2D(512, (3, 3), activation='elu', padding='same')(conv5)
    conv5 = BatchNormalization()(conv5)
    #conv5 = Conv2D(512, (3, 3), activation='elu', padding='same')(conv5)
    #conv5 = BatchNormalization()(conv5)
    #conv5 = Conv2D(512, (3, 3), activation='elu', padding='same')(conv5)
    #conv5 = BatchNormalization()(conv5)
    pool5 = MaxPooling2D(pool_size=(2, 2))(conv5)
    pool5 = Dropout(0.25)(pool5)
    # pool5 = Dropout(0.5)(pool5) ##20200518
    d_conv_output = pool5


    dense1 = Flatten()(d_conv_output)
    #dense2 = Dense(512, activation="elu", kernel_regularizer=regularizers.l2(1e-3))(dense1)
    
    #dense2 = Dense(512, activation="elu", kernel_regularizer=regularizers.l1_l2(l1=1e-3, l2=1e-3))(dense1) ##20200519
    #dense2 = BatchNormalization()(dense2)
    
    ##dense2 = Dropout(0.5)(dense2) ########################
    #dense2 = Dropout(0.25)(dense2) ##20200519
    
    ## 20200519
    #dense3 = Dense(256, activation="elu", kernel_regularizer=regularizers.l1_l2(l1=1e-3, l2=1e-3))(dense2)
    #dense3 = BatchNormalization()(dense3)
    #dense3 = Dropout(0.5)(dense3)#######################
    dense4 = Dense(128, activation="elu", kernel_regularizer=regularizers.l1_l2(l1=1e-3, l2=1e-3))(dense1)
    dense4 = BatchNormalization()(dense4)
    dense4 = Dropout(0.25)(dense4) ####################
    
    
    d_outputs = Dense(2, activation="softmax")(dense4)
    # d_outputs = Dense(1, activation="sigmoid")(dense2)

    d_model = Model([inputs], [d_outputs])
    d_model.summary()

    return  d_model

# %% [markdown]
# ## 저장해둔 train, test set 불러오기

# %%
numpy_dir = './resize_reverse_crop_128/classifier/numpy_data' #20200515
numpy_data = './resize_reverse_crop_128/classifier/numpy_data/binary_image_data.npy' #20200515

# %%
X_train, X_test, y_train, y_test = np.load(numpy_data, allow_pickle=True)

X_train = np.expand_dims(X_train, axis=-1)
X_test = np.expand_dims(X_test, axis =-1)

print(X_train.shape)
print(X_train.shape[0])
print(np.bincount(y_train))
print(np.bincount(y_test))
# Out:
# (1380, 128, 128, 1)
# 1380
# [496 884]
# [62 92]

# %%
# Check X_train data by plotting befor training

ix = random.randint(1, X_train.shape[0])
plt.imshow(X_train[ix].reshape((128, 128)))
if y_train[ix] == 0:
    plt.title('normal')
elif y_train[ix] == 1:
    plt.title('fracture')
plt.show()

# %%
# _, _, image_size, channels = X_train.shape
# _, _, image_size, channels = X_train.shape
_, default_crop_rect_height, default_crop_rect_width, _ = X_train.shape ##20200516
X_train = X_train.astype('float32') / 127.5 - 1
X_test = X_test.astype('float32') / 127.5 - 1
# print(image_size, channels) ##20200516

# %% [markdown]
# ## 모델 컴파일

# %%
# classifier = classifier_model(image_size, channels)
classifier = classifier_model() ## 20200516
classifier.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(), metrics=['accuracy'])
# Out:
# Model: "model_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_14 (InputLayer)        (None, 128, 128, 1)       0
# _________________________________________________________________
# conv2d_203 (Conv2D)          (None, 128, 128, 32)      320
# _________________________________________________________________
# batch_normalization_225 (Bat (None, 128, 128, 32)      128
# _________________________________________________________________
# conv2d_204 (Conv2D)          (None, 128, 128, 32)      9248
# _________________________________________________________________
# batch_normalization_226 (Bat (None, 128, 128, 32)      128
# _________________________________________________________________
# conv2d_205 (Conv2D)          (None, 128, 128, 32)      9248
# _________________________________________________________________
# batch_normalization_227 (Bat (None, 128, 128, 32)      128
# _________________________________________________________________
# max_pooling2d_66 (MaxPooling (None, 64, 64, 32)        0
# _________________________________________________________________
# dropout_89 (Dropout)         (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_206 (Conv2D)          (None, 64, 64, 64)        18496
# _________________________________________________________________
# batch_normalization_228 (Bat (None, 64, 64, 64)        256
# _________________________________________________________________
# conv2d_207 (Conv2D)          (None, 64, 64, 64)        36928
# _________________________________________________________________
# batch_normalization_229 (Bat (None, 64, 64, 64)        256
# _________________________________________________________________
# conv2d_208 (Conv2D)          (None, 64, 64, 64)        36928
# _________________________________________________________________
# batch_normalization_230 (Bat (None, 64, 64, 64)        256
# _________________________________________________________________
# max_pooling2d_67 (MaxPooling (None, 32, 32, 64)        0
# _________________________________________________________________
# dropout_90 (Dropout)         (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_209 (Conv2D)          (None, 32, 32, 128)       73856
# _________________________________________________________________
# batch_normalization_231 (Bat (None, 32, 32, 128)       512
# _________________________________________________________________
# conv2d_210 (Conv2D)          (None, 32, 32, 128)       147584
# _________________________________________________________________
# batch_normalization_232 (Bat (None, 32, 32, 128)       512
# _________________________________________________________________
# conv2d_211 (Conv2D)          (None, 32, 32, 128)       147584
# _________________________________________________________________
# batch_normalization_233 (Bat (None, 32, 32, 128)       512
# _________________________________________________________________
# max_pooling2d_68 (MaxPooling (None, 16, 16, 128)       0
# _________________________________________________________________
# dropout_91 (Dropout)         (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_212 (Conv2D)          (None, 16, 16, 256)       295168
# _________________________________________________________________
# batch_normalization_234 (Bat (None, 16, 16, 256)       1024
# _________________________________________________________________
# conv2d_213 (Conv2D)          (None, 16, 16, 256)       590080
# _________________________________________________________________
# batch_normalization_235 (Bat (None, 16, 16, 256)       1024
# _________________________________________________________________
# conv2d_214 (Conv2D)          (None, 16, 16, 256)       590080
# _________________________________________________________________
# batch_normalization_236 (Bat (None, 16, 16, 256)       1024
# _________________________________________________________________
# max_pooling2d_69 (MaxPooling (None, 8, 8, 256)         0
# _________________________________________________________________
# dropout_92 (Dropout)         (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_215 (Conv2D)          (None, 8, 8, 512)         1180160
# _________________________________________________________________
# batch_normalization_237 (Bat (None, 8, 8, 512)         2048
# _________________________________________________________________
# conv2d_216 (Conv2D)          (None, 8, 8, 512)         2359808
# _________________________________________________________________
# batch_normalization_238 (Bat (None, 8, 8, 512)         2048
# _________________________________________________________________
# max_pooling2d_70 (MaxPooling (None, 4, 4, 512)         0
# _________________________________________________________________
# dropout_93 (Dropout)         (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten_14 (Flatten)         (None, 8192)              0
# _________________________________________________________________
# dense_37 (Dense)             (None, 128)               1048704
# _________________________________________________________________
# batch_normalization_239 (Bat (None, 128)               512
# _________________________________________________________________
# dropout_94 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_38 (Dense)             (None, 2)                 258
# =================================================================
# Total params: 6,554,818
# Trainable params: 6,549,634
# Non-trainable params: 5,184
# _________________________________________________________________

# %% [markdown]
# ### Set ModelCheckpoint and EalryStopping

# %%
# model_dir = './whole/x-ray/classifier/model'
# model_dir = './resize_reverse_crop_128/classifier/model'
model_dir = './resize_reverse_crop_128/classifier/remodeled' #20200516
makedirs(model_dir, exist_ok=True)

model_path = model_dir + "/remodeled_classifier_batchsize16_loss{val_loss:.2f}_acc{val_accuracy: .2f}_elu.h5" #20200516
# model_path = model_dir + "/fracture_normal_classify_model_batch_size20.model"
    
checkpoint = ModelCheckpoint(filepath=model_path, monitor='val_loss', verbose=1, save_best_only=True)
# checkpoint = ModelCheckpoint(filepath=model_path, monitor='accuracy', verbose=1, save_best_only=True)
# checkpoint = ModelCheckpoint(filepath=model_path, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)
# checkpoint = ModelCheckpoint(filepath=model_path, monitor='val_loss', verbose=1, save_best_only=False, mode='max')

early_stopping = EarlyStopping(monitor='val_loss', patience=100)

# %% [markdown]
# ## 모델 훈련

# %%
# # history = classifier.fit(X_train, y_train, batch_size=16, epochs=300, validation_split=0.3, callbacks=[checkpoint]) ##########
# history = classifier.fit(X_train, y_train, batch_size=16, epochs=2000, validation_split=0.15, callbacks=[checkpoint, early_stopping])
# # history = classifier.fit(X_train, y_train, batch_size=1, epochs=100, validation_split=0.15, callbacks=[checkpoint, early_stopping])

from livelossplot import PlotLossesKeras
history = classifier.fit(X_train, y_train, batch_size = 16, epochs=1000, validation_data=(X_test, y_test), callbacks=[PlotLossesKeras(), checkpoint], verbose=0)
# Out:
# accuracy
# 	validation       	 (min:    0.513, max:    0.903, cur:    0.883)
# 	training         	 (min:    0.559, max:    0.999, cur:    0.998)
# Loss
# 	validation       	 (min:    0.695, max:   35.862, cur:    0.695)
# 	training         	 (min:    0.201, max:   52.172, cur:    0.314)
#
# Epoch 00167: val_loss improved from 0.73868 to 0.69467, saving model to ./resize_reverse_crop_128/classifier/remodeled/remodeled_classifier_batchsize16_loss0.69_acc 0.88_elu.h5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-81-236ff0c71b59> in <module>
#       4
#       5 from livelossplot import PlotLossesKeras
# ----> 6 history = classifier.fit(X_train, y_train, batch_size = 16, epochs=1000, validation_data=(X_test, y_test), callbacks=[PlotLossesKeras(), checkpoint], verbose=0)
#
# C:\ProgramData\Anaconda3\envs\project\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# C:\ProgramData\Anaconda3\envs\project\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     194                     ins_batch[i] = ins_batch[i].toarray()
#     195
# --> 196                 outs = fit_function(ins_batch)
#     197                 outs = to_list(outs)
#     198                 for l, o in zip(out_labels, outs):
#
# C:\ProgramData\Anaconda3\envs\project\lib\site-packages\tensorflow_core\python\keras\backend.py in __call__(self, inputs)
#    3733     return nest.pack_sequence_as(
#    3734         self._outputs_structure,
# -> 3735         [x._numpy() for x in outputs],  # pylint: disable=protected-access
#    3736         expand_composites=True)
#    3737
#
# C:\ProgramData\Anaconda3\envs\project\lib\site-packages\tensorflow_core\python\keras\backend.py in <listcomp>(.0)
#    3733     return nest.pack_sequence_as(
#    3734         self._outputs_structure,
# -> 3735         [x._numpy() for x in outputs],  # pylint: disable=protected-access
#    3736         expand_composites=True)
#    3737
#
# C:\ProgramData\Anaconda3\envs\project\lib\site-packages\tensorflow_core\python\framework\ops.py in _numpy(self)
#     906     # pylint: disable=protected-access
#     907     try:
# --> 908       return self._numpy_internal()
#     909     except core._NotOkStatusException as e:
#     910       six.raise_from(core._status_to_exception(e.code, e.message), None)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Accuracy

# %%
print("정확도 : %.2f " %(classifier.evaluate(X_test, y_test)[1]))
# Out:
# 154/154 [==============================] - 0s 2ms/step
# 정확도 : 0.60

# %% [markdown]
# ### 그래프: loss, accuracy

# %%
# import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
# plt.plot(history.history['acc'])
plt.plot(history.history['accuracy'])
# plt.plot(history.history['val_acc'])
plt.plot(history.history['val_accuracy'])
plt.title('model loss - elu')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss', 'val_loss', 'accuracy', 'val_accuracy'], loc='upper left')
plt.show()

# %%
# import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
# plt.plot(history.history['acc'])
plt.plot(history.history['accuracy'])
# plt.plot(history.history['val_acc'])
plt.plot(history.history['val_accuracy'])
plt.title('model loss - elu')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss', 'val_loss', 'accuracy', 'val_accuracy'], loc='upper left')
plt.show()

# %% [markdown]
# ## Classifier model 검증하기 (Test directory)

# %%
# from PIL import Image
# import os, glob, random, numpy as np
# from keras.models import load_model
# import tensorflow as tf
# import matplotlib.pyplot as plt
# from matplotlib.image import imread

seed = 5
# tf.set_random_seed(seed)
np.random.seed(seed)

caltech_dir = './resize_reverse_crop_128/classifier/images/test' #20200515


# img_w = 224
img_w = 128 #20200515
# img_h = 224
img_h = 128 #20200515
# channel = 3
channel = 1

pixels = img_h * img_w * channel

X = []
filenames = []
files = glob.glob(caltech_dir + "/*/*.*")
for i, f in enumerate(files):
    img = Image.open(f).convert('L') #20200515
    # img = img.convert('RGB')
    img = img.resize((img_w, img_h))
    data = np.asarray(img)

    filenames.append(f)
    X.append(data)

X = np.array(X)

# ##20200518
# shuffled_train_index = np.random.permutation(X.shape[0])
# X = X[shuffled_train_index,:,:]
# print(X.shape)

ix = random.randint(1, X.shape[0])
plt.imshow(X[ix])
plt.show()

# %%
X = np.expand_dims(X, axis=-1)
X = X.astype(float) / 127.5 - 1

# %% [markdown]
# ### prediction and result

# %%
# model = load_model('./whole/x-ray/classifier/model/fracture_normal_classify.model')
# model = load_model('./whole/x-ray/classifier/model/fracture_normal_classify_model.model')

model = load_model('./resize_reverse_crop_128/classifier/remodeled/remodeled_classifier_batchsize16_loss0.42_acc 0.86_elu.h5') #20200518

prediction = model.predict(X)

np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})

cnt = 0
for i in prediction:
    if i[1] >= 0.5: ##20200518
      print("해당 " + filenames[cnt].split("\\")[-2] + ' ' + filenames[cnt].split("\\")[-1] + "  이미지는 1: 골절 로 추정됩니다.")
    else :
      print("해당 " + filenames[cnt].split("\\")[-2] + ' ' + filenames[cnt].split("\\")[-1] + "  이미지는 0: 비골절 로 추정됩니다.")
    cnt += 1
# Out:
# 해당 fracture 1048l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1049l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1049r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1052r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1055l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1057r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1060r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1063l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1066l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1066r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1067l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1069r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1074l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1075l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1082l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1084r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1087l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1090r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1095r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 1098l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1099r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 10r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1107l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 1108l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1113l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1114l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1122l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1125r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1127l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1127r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 112r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1137l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1140r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1145r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1147l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1149l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1152r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1163r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1165r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1166r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 1167l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1169r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 116r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1173r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1176l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1177l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1181r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1185r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1193r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1196r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 120l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1222r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1228l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1228r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 122r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1237r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 123r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1242r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1247l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1265l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1270r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 1271l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1298l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1301l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1307r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1313l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1313r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1318l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1326l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 132l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1331l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1334r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1339l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1339r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1347r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1350l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1350r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1361l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1364l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1365r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1372l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1372r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1373r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 137l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1389l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1389r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 138l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1392r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1395r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1399r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1400l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1407r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1408r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1430r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1440r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1442l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1449l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 144r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 1464r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1465l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1475r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1477r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1485r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 148r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1490l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1493l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 14r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 153r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 159r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 168l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 169r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 16r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1707l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 173r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 180r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 182l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 187l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 194l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 198r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 201l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 203r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 208r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 211r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 214l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 219l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 219r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 221r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 224r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 227r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 228l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 229r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 234l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 238r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 23l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 243r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 245r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 248r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 251l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 259l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 261r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 277l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 277r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 279l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 27l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 284r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 289r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 296r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 29r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 301l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 302r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 303l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 309r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 313l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 313r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 315l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 318l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 31l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 324r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 325l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 328r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 331r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 337l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 34l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 351r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 352l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 356l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 358r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 364r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 370l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 378l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 381r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 384r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 390l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 392l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 393l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 393r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 395l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 396l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 39l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 402r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 407r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 409l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 422r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 423l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 424r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 42r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 433l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 433r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 435r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 436r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 441l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 442r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 443r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 448r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 449r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 454l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 455l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 458l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 458r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 463r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 464l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 471l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 472r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 474l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 480r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 483r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 487l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 487r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 488l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 488r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 489r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 491r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 492l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 493l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 493r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 494l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 495r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 497l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 50l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 5r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 70r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 74r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 76r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 90r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 94r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 97r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 98l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 9r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 103r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 104l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1058l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1231r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1240l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1240r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 124r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1250r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 1257l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1257r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1258l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 1258r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1284r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1285l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1288l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 1299l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1353l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1353r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1357r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1366l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 1376l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1378l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1398l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 1402l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1406l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1414l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1427r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1435l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 143r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1447l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1452r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1454l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1458r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1459r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1460r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1461r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1482r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1505l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1510l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 1512r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1525l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1525r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1527l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 1537l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1543l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1545r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 1551r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1554l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1555r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1559l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1561r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1562r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1563r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 1564r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1565l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 1567r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1568l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 1568r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 156l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 1572r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1575r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1577r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1582l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1586l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1586r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1597r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1610r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1612r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1616l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1616r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1617l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 1621l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1625r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1628r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1633r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1645l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 1648l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1651l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1654l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 1654r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 1656l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 1657r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1658r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1665l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1666r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1668r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 1672l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 1673l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1673r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1679r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1683r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1687r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1690r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1697l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1701l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1706l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1711r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 1712r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1717l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1718r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1719r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 1726l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1733r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1736r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1739l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 1740l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1741r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1742r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 1744r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1747l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1748l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1748r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1750r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1751r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1753r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1754r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1756r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1760r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1762l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 1766l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1776l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1777l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1777r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 1779l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1781r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1786l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1786r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 256r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 285l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 285r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 304l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 304r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 394r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 417l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 417r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 46l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 51r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 61r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 83r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 87r.jpg  이미지는 0: 비골절 로 추정됩니다.

# %%
print(prediction)
# Out:
# [[0.187 0.813]
#  [0.179 0.821]
#  [0.128 0.872]
#  [0.025 0.975]
#  [0.054 0.946]
#  [0.061 0.939]
#  [0.064 0.936]
#  [0.081 0.919]
#  [0.206 0.794]
#  [0.114 0.886]
#  [0.136 0.864]
#  [0.017 0.983]
#  [0.296 0.704]
#  [0.066 0.934]
#  [0.322 0.678]
#  [0.071 0.929]
#  [0.055 0.945]
#  [0.046 0.954]
#  [0.958 0.042]
#  [0.100 0.900]
#  [0.104 0.896]
#  [0.042 0.958]
#  [0.849 0.151]
#  [0.863 0.137]
#  [0.070 0.930]
#  [0.015 0.985]
#  [0.084 0.916]
#  [0.009 0.991]
#  [0.077 0.923]
#  [0.400 0.600]
#  [0.274 0.726]
#  [0.019 0.981]
#  [0.093 0.907]
#  [0.059 0.941]
#  [0.098 0.902]
#  [0.125 0.875]
#  [0.041 0.959]
#  [0.248 0.752]
#  [0.095 0.905]
#  [0.442 0.558]
#  [0.044 0.956]
#  [0.032 0.968]
#  [0.250 0.750]
#  [0.106 0.894]
#  [0.069 0.931]
#  [0.077 0.923]
#  [0.031 0.969]
#  [0.374 0.626]
#  [0.264 0.736]
#  [0.093 0.907]
#  [0.182 0.818]
#  [0.033 0.967]
#  [0.270 0.730]
#  [0.081 0.919]
#  [0.109 0.891]
#  [0.633 0.367]
#  [0.316 0.684]
#  [0.088 0.912]
#  [0.088 0.912]
#  [0.177 0.823]
#  [0.916 0.084]
#  [0.074 0.926]
#  [0.102 0.898]
#  [0.051 0.949]
#  [0.047 0.953]
#  [0.098 0.902]
#  [0.113 0.887]
#  [0.650 0.350]
#  [0.063 0.937]
#  [0.061 0.939]
#  [0.007 0.993]
#  [0.020 0.980]
#  [0.016 0.984]
#  [0.022 0.978]
#  [0.104 0.896]
#  [0.017 0.983]
#  [0.035 0.965]
#  [0.291 0.709]
#  [0.016 0.984]
#  [0.072 0.928]
#  [0.369 0.631]
#  [0.037 0.963]
#  [0.032 0.968]
#  [0.135 0.865]
#  [0.030 0.970]
#  [0.029 0.971]
#  [0.163 0.837]
#  [0.469 0.531]
#  [0.035 0.965]
#  [0.032 0.968]
#  [0.027 0.973]
#  [0.037 0.963]
#  [0.029 0.971]
#  [0.272 0.728]
#  [0.042 0.958]
#  [0.024 0.976]
#  [0.056 0.944]
#  [0.204 0.796]
#  [0.049 0.951]
#  [0.038 0.962]
#  [0.030 0.970]
#  [0.037 0.963]
#  [0.040 0.960]
#  [0.044 0.956]
#  [0.030 0.970]
#  [0.065 0.935]
#  [0.410 0.590]
#  [0.091 0.909]
#  [0.538 0.462]
#  [0.526 0.474]
#  [0.343 0.657]
#  [0.181 0.819]
#  [0.060 0.940]
#  [0.088 0.912]
#  [0.037 0.963]
#  [0.291 0.709]
#  [0.315 0.685]
#  [0.635 0.365]
#  [0.057 0.943]
#  [0.074 0.926]
#  [0.119 0.881]
#  [0.293 0.707]
#  [0.891 0.109]
#  [0.798 0.202]
#  [0.066 0.934]
#  [0.070 0.930]
#  [0.124 0.876]
#  [0.281 0.719]
#  [0.133 0.867]
#  [0.378 0.622]
#  [0.204 0.796]
#  [0.692 0.308]
#  [0.119 0.881]
#  [0.119 0.881]
#  [0.431 0.569]
#  [0.424 0.576]
#  [0.090 0.910]
#  [0.435 0.565]
#  [0.269 0.731]
#  [0.247 0.753]
#  [0.192 0.808]
#  [0.047 0.953]
#  [0.223 0.777]
#  [0.212 0.788]
#  [0.074 0.926]
#  [0.623 0.377]
#  [0.154 0.846]
#  [0.261 0.739]
#  [0.334 0.666]
#  [0.089 0.911]
#  [0.373 0.627]
#  [0.277 0.723]
#  [0.376 0.624]
#  [0.199 0.801]
#  [0.086 0.914]
#  [0.039 0.961]
#  [0.063 0.937]
#  [0.079 0.921]
#  [0.024 0.976]
#  [0.119 0.881]
#  [0.055 0.945]
#  [0.072 0.928]
#  [0.126 0.874]
#  [0.076 0.924]
#  [0.467 0.533]
#  [0.016 0.984]
#  [0.727 0.273]
#  [0.168 0.832]
#  [0.077 0.923]
#  [0.281 0.719]
#  [0.701 0.299]
#  [0.135 0.865]
#  [0.142 0.858]
#  [0.137 0.863]
#  [0.245 0.755]
#  [0.209 0.791]
#  [0.609 0.391]
#  [0.134 0.866]
#  [0.857 0.143]
#  [0.036 0.964]
#  [0.092 0.908]
#  [0.467 0.533]
#  [0.879 0.121]
#  [0.375 0.625]
#  [0.055 0.945]
#  [0.059 0.941]
#  [0.747 0.253]
#  [0.690 0.310]
#  [0.042 0.958]
#  [0.759 0.241]
#  [0.010 0.990]
#  [0.053 0.947]
#  [0.050 0.950]
#  [0.135 0.865]
#  [0.379 0.621]
#  [0.096 0.904]
#  [0.569 0.431]
#  [0.021 0.979]
#  [0.053 0.947]
#  [0.033 0.967]
#  [0.120 0.880]
#  [0.053 0.947]
#  [0.160 0.840]
#  [0.076 0.924]
#  [0.591 0.409]
#  [0.374 0.626]
#  [0.038 0.962]
#  [0.589 0.411]
#  [0.645 0.355]
#  [0.098 0.902]
#  [0.014 0.986]
#  [0.058 0.942]
#  [0.144 0.856]
#  [0.727 0.273]
#  [0.139 0.861]
#  [0.051 0.949]
#  [0.057 0.943]
#  [0.136 0.864]
#  [0.548 0.452]
#  [0.158 0.842]
#  [0.027 0.973]
#  [0.106 0.894]
#  [0.177 0.823]
#  [0.073 0.927]
#  [0.083 0.917]
#  [0.142 0.858]
#  [0.813 0.187]
#  [0.051 0.949]
#  [0.740 0.260]
#  [0.781 0.219]
#  [0.904 0.096]
#  [0.706 0.294]
#  [0.613 0.387]
#  [0.899 0.101]
#  [0.928 0.072]
#  [0.036 0.964]
#  [0.702 0.298]
#  [0.972 0.028]
#  [0.527 0.473]
#  [0.928 0.072]
#  [0.944 0.056]
#  [0.781 0.219]
#  [0.428 0.572]
#  [0.811 0.189]
#  [0.952 0.048]
#  [0.886 0.114]
#  [0.397 0.603]
#  [0.717 0.283]
#  [0.930 0.070]
#  [0.394 0.606]
#  [0.925 0.075]
#  [0.862 0.138]
#  [0.951 0.049]
#  [0.595 0.405]
#  [0.799 0.201]
#  [0.958 0.042]
#  [0.788 0.212]
#  [0.972 0.028]
#  [0.747 0.253]
#  [0.922 0.078]
#  [0.837 0.163]
#  [0.731 0.269]
#  [0.668 0.332]
#  [0.964 0.036]
#  [0.975 0.025]
#  [0.650 0.350]
#  [0.258 0.742]
#  [0.106 0.894]
#  [0.801 0.199]
#  [0.859 0.141]
#  [0.173 0.827]
#  [0.786 0.214]
#  [0.966 0.034]
#  [0.686 0.314]
#  [0.952 0.048]
#  [0.908 0.092]
#  [0.964 0.036]
#  [0.769 0.231]
#  [0.883 0.117]
#  [0.535 0.465]
#  [0.195 0.805]
#  [0.869 0.131]
#  [0.141 0.859]
#  [0.464 0.536]
#  [0.103 0.897]
#  [0.741 0.259]
#  [0.075 0.925]
#  [0.741 0.259]
#  [0.784 0.216]
#  [0.697 0.303]
#  [0.838 0.162]
#  [0.809 0.191]
#  [0.884 0.116]
#  [0.944 0.056]
#  [0.919 0.081]
#  [0.755 0.245]
#  [0.714 0.286]
#  [0.945 0.055]
#  [0.085 0.915]
#  [0.887 0.113]
#  [0.965 0.035]
#  [0.967 0.033]
#  [0.635 0.365]
#  [0.413 0.587]
#  [0.175 0.825]
#  [0.427 0.573]
#  [0.110 0.890]
#  [0.089 0.911]
#  [0.617 0.383]
#  [0.939 0.061]
#  [0.551 0.449]
#  [0.882 0.118]
#  [0.492 0.508]
#  [0.228 0.772]
#  [0.385 0.615]
#  [0.330 0.670]
#  [0.910 0.090]
#  [0.948 0.052]
#  [0.848 0.152]
#  [0.822 0.178]
#  [0.903 0.097]
#  [0.963 0.037]
#  [0.926 0.074]
#  [0.767 0.233]
#  [0.623 0.377]
#  [0.767 0.233]
#  [0.961 0.039]
#  [0.710 0.290]
#  [0.419 0.581]
#  [0.944 0.056]
#  [0.872 0.128]
#  [0.932 0.068]
#  [0.117 0.883]
#  [0.966 0.034]
#  [0.814 0.186]
#  [0.047 0.953]
#  [0.426 0.574]
#  [0.967 0.033]
#  [0.939 0.061]
#  [0.674 0.326]
#  [0.953 0.047]
#  [0.945 0.055]
#  [0.584 0.416]
#  [0.929 0.071]
#  [0.859 0.141]
#  [0.922 0.078]
#  [0.718 0.282]
#  [0.648 0.352]
#  [0.772 0.228]
#  [0.979 0.021]
#  [0.187 0.813]
#  [0.952 0.048]
#  [0.061 0.939]
#  [0.857 0.143]
#  [0.088 0.912]
#  [0.909 0.091]
#  [0.231 0.769]
#  [0.040 0.960]
#  [0.154 0.846]
#  [0.111 0.889]
#  [0.823 0.177]
#  [0.799 0.201]
#  [0.668 0.332]
#  [0.476 0.524]
#  [0.930 0.070]
#  [0.103 0.897]
#  [0.477 0.523]
#  [0.262 0.738]]

# %%
# import matplotlib.pyplot as plt
plt.hist(prediction, bins=50)
plt.show()

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

cnt = 0

TF = []
FF = []
TN = []
FN = []
for i in prediction:
  if i[1] >= 0.5: ##20200518
    if filenames[cnt].split("\\")[-2] == 'fracture':
      TF.append(i)
    elif filenames[cnt].split("\\")[-2] == 'normal':
      FF.append(i)
  else:
    if filenames[cnt].split("\\")[-2] == 'normal':
      TN.append(i)
    elif filenames[cnt].split("\\")[-2] == 'fracture':
      FN.append(i)
  cnt += 1



df = pd.DataFrame({'cross result':['True Fracture', 'False Fracture', 'True Normal', 'False Normal'], 'count':[len(TF), len(FF), len(TN), len(FN)]})
ax = df.plot.bar(x='cross result', y='count', rot=0)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
plt.show()
