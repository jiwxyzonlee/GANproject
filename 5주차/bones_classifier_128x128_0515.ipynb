# %% [markdown]
# # 비골절, 골절 Classifier

# %% [markdown]
# ## colab 에서 진행할 경우 (이외 건너뛰어도 무방)
# - 드라이브 마운트 필요

# %%
# to find the directory you're in ,
# !ls
#if you wanna go into a folder (say samplefolder)
# %cd /content/drive/My Drive
# Out:
# drive  sample_data
# /content/drive/My Drive

# %%
import os
os.getcwd()
# Out:
# '/content/drive/My Drive'

# %%
# !unzip whole.zip -d whole
# !unzip resize_reverse_crop.zip -d resize_reverse_crop
# !unzip resize_reverse_crop_128.zip -d resize_reverse_crop_128

# %% [markdown]
# ## Load module

# %%
from __future__ import print_function, division

from keras import optimizers, initializers, regularizers, metrics
from keras.layers import Input, Dense, Flatten, Dropout
from keras.layers import BatchNormalization, Activation, MaxPooling2D
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.convolutional import Conv2D
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Model, load_model
from keras.optimizers import RMSprop
# from keras.models import Sequential

from os import makedirs
from os import listdir

from shutil import copyfile
from random import seed
from random import random

from matplotlib.image import imread

from PIL import Image

from sklearn.model_selection import train_test_split
from keras.utils import np_utils


# from functools import partial

import random
import keras.backend as K
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
import glob
import os
# import keras.backend.tensorflow_backend as K
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Source Data 확인
# /content/drive/My Drive/resize_reverse_crop/Normal_resize_reverse_crop_128\
# /content/drive/My Drive/resize_reverse_crop/fracture_resize_reverse_crop_128\
#
# /content/drive/My Drive/resize_reverse_crop/Normal_resize_reverse_crop\
# /content/drive/My Drive/resize_reverse_crop/fracture_resize_reverse_crop\
#
# /content/drive/My Drive/whole/x-ray/Normal_resize_reverse_crop\
# /content/drive/My Drive/whole/x-ray/fracture_resize_reverse_crop

# %%
path_normal ='./resize_reverse_crop_128/Normal_resize_reverse_crop' #20200515
path_fracture = './resize_reverse_crop_128/fracture_resize_reverse_crop' #20200515

normal_image_path_names = []
fracture_image_path_names = []

# Get Images in folders
for file_n in glob.glob(path_normal + '/*.jpg'):
  normal_image_path_names.append(file_n)

for file_f in glob.glob(path_fracture + '/*.jpg'):
  fracture_image_path_names.append(file_f)

# Check if training data looks all right

fig, axs = plt.subplots(2, 10, figsize=(15, 5))
for i in range(10) :
  img_normal = imread(normal_image_path_names[i])
  img_fracture = imread(fracture_image_path_names[i])
  fig.suptitle('Normal and Fractured', fontsize=14)
  axs[0, i].set_axis_off()
  axs[0, i].set_title('Normal{}'.format(i+1))
  axs[0, i].imshow(img_normal, cmap='gray')
  axs[1, i].set_axis_off()
  axs[1, i].set_title('Fracture{}'.format(i+1))
  axs[1, i].imshow(img_fracture, cmap='gray')

# %%
print(img_normal.shape)
print(img_fracture.shape)
# Out:
# (128, 128, 3)
# (128, 128, 3)

# %%
print(len(normal_image_path_names))
print(len(fracture_image_path_names))
# Out:
# 698
# 1204

# %% [markdown]
# ## Train set, Test set 디렉토리 분류
# ###  이미 디렉토리 안에 파일이 생성되어 있는 경우 지나가도 됨
#
#  classifier\
#    ├── test\
#    │   ├── fracture\
#    │   └── normal\
#    └── train\
#   ----      ├── fracture\
#   ----      └── normal
#
#
#
# Ref:\
# https://machinelearningmastery.com/how-to-develop-a-convolutional-neural-network-to-classify-photos-of-dogs-and-cats/

# %%
# organize dataset into a useful structure

# from os import makedirs
# from os import listdir
# from shutil import copyfile
# from random import seed
# from random import random

## Step1
# create directories
dataset_home = './resize_reverse_crop_128/classifier/' #20200515
subdirs = ['images/train/', 'images/test/']
labeldirs = ['fracture/', 'normal/']

for subdir in subdirs:
  for labeldir in labeldirs:
    newdir = dataset_home + subdir + labeldir
    makedirs(newdir, exist_ok=True)
print('== Step1 is done ==')


## Step2
# seed random number generator
seed(1)

# define ratio of pictures to use for validation
val_ratio = 0.2
# val_ratio = 0.3

# copy training dataset images into subdirectories

path_normal = './resize_reverse_crop_128/Normal_resize_reverse_crop' #20200515
path_fracture = './resize_reverse_crop_128/fracture_resize_reverse_crop' #20200515


src_path = [path_fracture, path_normal]
for path in src_path:
  for file in listdir(path):
    src = path + '/' + file # './resize_reverse_crop_128/Normal_resize_reverse_crop/*.jpg'
    lab_dir = path.split('/')[-1].split('_')[0].lower() # fracture, normal
    if random() > val_ratio:
      subdir = 'images/train/'
      dst = dataset_home + subdir + lab_dir + '/'  + file # '.classifier/images/클래스(fracture, normal)'
      copyfile(src, dst)
    else:
      subdir = 'images/test/'
      dst = dataset_home + subdir + lab_dir + '/'  + file # '.classifier/images/클래스(fracture, normal)'
      copyfile(src, dst)
print('== Step2 is done ==')
# Out:
# == Step1 is done ==
# == Step2 is done ==

# %% [markdown]
# ## X_train, X_test, Y_train, Y_test 마련

# %% [markdown]
# Ref:\
# https://github.com/lsjsj92/keras_basic/blob/master/6.%20predict_binary_img_with_CNN.ipynb

# %%
# from PIL import Image
# import os, glob, sys, numpy as np
# from os import makedirs
# from sklearn.model_selection import train_test_split
# from keras.utils import np_utils

img_dir = './resize_reverse_crop_128/classifier/images/train' #20200515
# categories = list(class_names)
categories = ['normal', 'fracture']
np_classes = len(categories)

img_w = 128 #20200515
img_h = 128 #20200515
# channel = 3
channel = 1 #20200515

pixel = img_w * img_h * channel

X = []
y = []

for idx, category in enumerate(categories):
  img_dir_detail = img_dir + '/' + category
  files = glob.glob(img_dir_detail + '/*.jpg')

  for i, f in enumerate(files):
    try:
      img = Image.open(f).convert('L') #20200515
      # img = img.convert('RGB')
      img = img.resize((img_w, img_h))
      data = np.asarray(img)
      # print(data.shape)
      X.append(data)
      y.append(idx)
      if i % 300 == 0:
        print(category, ":", f)
    except:
      print(category, str(i), 'Error')

X = np.array(X)
Y = np.array(y)

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.1)

xy = (X_train, X_test, Y_train, Y_test)
# Out:
# normal : ./resize_reverse_crop_128/classifier/images/train/normal/1035l.jpg
# normal 55 Error
# normal 82 Error

# %%
# Check X_train data by plotting

# import random
# import matplotlib.pyplot as plt
# from matplotlib.image import imread

ix = random.randint(1, X_train.shape[0])
plt.imshow(X_train[ix])
if Y_train[ix] == 0:
  plt.title('normal')
elif Y_train[ix] == 1:
  plt.title('fracture')
plt.show()

# %% [markdown]
# ### 나눈 Train and Test set을 numpy data로 저장

# %%
numpy_dir = './resize_reverse_crop_128/classifier/numpy_data' #20200515
numpy_data = './resize_reverse_crop_128/classifier/numpy_data/binary_image_data.npy' #20200515

makedirs(numpy_dir, exist_ok=True)
np.save(numpy_data, xy)

# %% [markdown]
# ## Classifier model

# %%
# from keras.models import Sequential
# from keras.optimizers import RMSprop
# from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
# from keras.callbacks import EarlyStopping, ModelCheckpoint
# from matplotlib.image import imread
# import matplotlib.pyplot as plt
# import keras.backend.tensorflow_backend as K
# import random

# %% [markdown]
# ### loss 0.39 acc 0.87

# %%
# loss 0.39 acc 0.87

def classifier_model(img_size, channels):
    inputs = Input(shape=(img_size, img_size, channels))
    depth = 8

    conv0 = Conv2D(depth*1, (3,3), padding='same')(inputs)
    conv0 = LeakyReLU(0.2)(conv0)
    bat0 = BatchNormalization()(conv0)
    # drop0 = Dropout(0.1)(bat0)
    drop0 = Dropout(0.1)(bat0)
    # conv0 = Conv2D(depth, (3,3), padding='same')(bat0)
    # conv0 = LeakyReLU(0.2)(conv0)
    # bat0 = BatchNormalization()(conv0)
    pool0 = MaxPooling2D(pool_size=(2,2))(drop0)
    drop0 = Dropout(0.1)(pool0)

    conv1 = Conv2D(depth*2, (3,3), padding='same')(drop0)
    conv1 = LeakyReLU(0.2)(conv1)
    bat1 = BatchNormalization()(conv1)
    drop1 = Dropout(0.1)(bat1)
    # conv1 = Conv2D(depth*2, (3,3), padding='same')(bat1)
    # conv1 = LeakyReLU(0.2)(conv1)
    # bat1 = BatchNormalization()(conv1)
    pool1 = MaxPooling2D(pool_size=(2,2))(drop1)
    drop1 = Dropout(0.1)(pool1)

    conv2 = Conv2D(depth*4, (3,3), padding='same')(drop1)
    conv2 = LeakyReLU(0.2)(conv2)
    bat2 = BatchNormalization()(conv2)
    drop2 = Dropout(0.1)(bat2)
    # conv2 = Conv2D(depth*4, (5,5), padding='same')(bat2)
    # conv2 = LeakyReLU(0.2)(conv2)
    # bat2 = BatchNormalization()(conv2)
    pool2 = MaxPooling2D(pool_size=(2,2))(drop2)
    drop2 = Dropout(0.1)(pool2)

    conv3 = Conv2D(depth*8, (3,3), padding='same')(drop2)
    conv3 = LeakyReLU(0.2)(conv3)
    bat3 = BatchNormalization()(conv3)
    drop3 = Dropout(0.5)(bat3)
    # conv3 = Conv2D(depth*8, (3,3), padding='same')(bat3)
    # conv3 = LeakyReLU(0.2)(conv3)
    # bat3 = BatchNormalization()(conv3)
    pool3 = MaxPooling2D(pool_size=(2,2))(drop3)
    drop3 = Dropout(0.1)(pool3)

    conv4 = Conv2D(depth*16, (3,3), padding='same')(drop3)
    conv4 = LeakyReLU(0.2)(conv4)
    bat4 = BatchNormalization()(conv4)
    drop4 = Dropout(0.1)(bat4)
    # conv4 = Conv2D(depth*16, (3,3), padding='same')(bat4)
    # conv4 = LeakyReLU(0.2)(conv4)
    # bat4 = BatchNormalization()(conv4)
    pool4 = MaxPooling2D(pool_size=(2,2))(drop4)
    drop4 = Dropout(0.1)(pool4)

    conv5 = Conv2D(depth*32, (3,3), padding='same')(drop4)
    conv5 = LeakyReLU(0.2)(conv5)
    bat5 = BatchNormalization()(conv5)
    drop5 = Dropout(0.1)(bat5)
    # conv5 = Conv2D(depth*32, (3,3))(drop5)
    # conv5 = LeakyReLU(0.2)(conv5)
    # bat5 = BatchNormalization()(conv5)
    pool5 = MaxPooling2D(pool_size=(2,2))(drop5)
    drop5 = Dropout(0.1)(pool5)

    conv6 = Conv2D(depth*64, (3,3), padding='same')(drop5)
    conv6 = LeakyReLU(0.2)(conv6)
    bat6 = BatchNormalization()(conv6)
    drop6 = Dropout(0.25)(bat6)
    # drop6 = Dropout(0.5)(bat6)
    # conv6 = Conv2D(depth*64, (3,3))(drop5)
    # conv6 = LeakyReLU(0.2)(conv6)
    # bat6 = BatchNormalization()(conv6)
    pool6 = MaxPooling2D(pool_size=(2,2))(drop6)
    drop6 = Dropout(0.25)(pool6)
    # drop6 = Dropout(0.5)(pool6)

    conv7 = Conv2D(depth*128, (3,3), padding='same')(drop6)
    conv7 = LeakyReLU(0.2)(conv7)
    bat7 = BatchNormalization()(conv7)
    drop7 = Dropout(0.25)(bat7) 
    # drop7 = Dropout(0.5)(bat7)

    fc = Flatten()(drop7)
    fc = Dense(depth*128, kernel_regularizer=regularizers.l2(1e-4))(fc)
    fc = LeakyReLU(0.2)(fc)
    fc = Dropout(0.5)(fc)
    fc = Dense(1)(fc)
    outputs = Activation('sigmoid')(fc)

    model = Model(inputs=[inputs], outputs=[outputs])
    model.summary()

    return model

# %% [markdown]
# ### mixed kernel

# %%
#mixed kernel

def classifier_model(img_size, channels):
  inputs = Input(shape=(img_size, img_size, channels))
  depth = 8
      
  conv0 = Conv2D(depth*1, (3,3), padding='same')(inputs)
  conv0 = LeakyReLU(0.2)(conv0)
  bat0 = BatchNormalization()(conv0)
  drop0 = Dropout(0.1)(bat0)
  # conv0 = Conv2D(depth, (3,3), padding='same')(bat0)
  # conv0 = LeakyReLU(0.2)(conv0)
  # bat0 = BatchNormalization()(conv0)
  pool0 = MaxPooling2D(pool_size=(2,2))(drop0)
  drop0 = Dropout(0.1)(pool0)
      
  conv1 = Conv2D(depth*2, (3,3), padding='same')(drop0) #######################
  conv1 = LeakyReLU(0.2)(conv1)
  bat1 = BatchNormalization()(conv1)
  drop1 = Dropout(0.1)(bat1)
  # conv1 = Conv2D(depth*2, (3,3), padding='same')(bat1)
  # conv1 = LeakyReLU(0.2)(conv1)
  # bat1 = BatchNormalization()(conv1)
  pool1 = MaxPooling2D(pool_size=(2,2))(drop1)
  drop1 = Dropout(0.1)(pool1)
      
  conv2 = Conv2D(depth*4, (5,5), padding='same')(drop1) ###########################
  conv2 = LeakyReLU(0.2)(conv2)
  bat2 = BatchNormalization()(conv2)
  drop2 = Dropout(0.1)(bat2)
  # conv2 = Conv2D(depth*4, (5,5), padding='same')(bat2)
  # conv2 = LeakyReLU(0.2)(conv2)
  # bat2 = BatchNormalization()(conv2)
  pool2 = MaxPooling2D(pool_size=(2,2))(drop2)
  drop2 = Dropout(0.1)(pool2)
      
  conv3 = Conv2D(depth*8, (3,3), padding='same')(drop2)
  conv3 = LeakyReLU(0.2)(conv3)
  bat3 = BatchNormalization()(conv3)
  drop3 = Dropout(0.5)(bat3)
  # conv3 = Conv2D(depth*8, (3,3), padding='same')(bat3)
  # conv3 = LeakyReLU(0.2)(conv3)
  # bat3 = BatchNormalization()(conv3)
  pool3 = MaxPooling2D(pool_size=(2,2))(drop3)
  drop3 = Dropout(0.1)(pool3)
      
  conv4 = Conv2D(depth*16, (3,3), padding='same')(drop3) #################
  conv4 = LeakyReLU(0.2)(conv4)
  bat4 = BatchNormalization()(conv4)
  drop4 = Dropout(0.1)(bat4)
  # conv4 = Conv2D(depth*16, (3,3), padding='same')(bat4)
  # conv4 = LeakyReLU(0.2)(conv4)
  # bat4 = BatchNormalization()(conv4)
  pool4 = MaxPooling2D(pool_size=(2,2))(drop4)
  drop4 = Dropout(0.1)(pool4)
      
  conv5 = Conv2D(depth*32, (5,5), padding='same')(drop4)
  conv5 = LeakyReLU(0.2)(conv5)
  bat5 = BatchNormalization()(conv5)
  drop5 = Dropout(0.1)(bat5)
  # conv5 = Conv2D(depth*32, (3,3))(drop5)
  # conv5 = LeakyReLU(0.2)(conv5)
  # bat5 = BatchNormalization()(conv5)
  pool5 = MaxPooling2D(pool_size=(2,2))(drop5)
  drop5 = Dropout(0.1)(pool5)
      
  conv6 = Conv2D(depth*64, (4,4), padding='same')(drop5) ##################
  conv6 = LeakyReLU(0.2)(conv6)
  bat6 = BatchNormalization()(conv6)
  drop6 = Dropout(0.25)(bat6)
  # drop6 = Dropout(0.5)(bat6)
  # conv6 = Conv2D(depth*64, (3,3))(drop5)
  # conv6 = LeakyReLU(0.2)(conv6)
  # bat6 = BatchNormalization()(conv6)
  pool6 = MaxPooling2D(pool_size=(2,2))(drop6)
  drop6 = Dropout(0.25)(pool6)
  # drop6 = Dropout(0.5)(pool6)
      
  conv7 = Conv2D(depth*64, (4,4), padding='same')(drop6) ###################
  conv7 = LeakyReLU(0.2)(conv7)
  bat7 = BatchNormalization()(conv7)
  drop7 = Dropout(0.25)(bat7) 
  # drop7 = Dropout(0.5)(bat7)
      
  fc = Flatten()(drop7)
  fc = Dense(depth*128, kernel_regularizer=regularizers.l2(1e-4))(fc)
  fc = LeakyReLU(0.2)(fc)
  fc = Dropout(0.5)(fc)
  fc = Dense(1)(fc)
  outputs = Activation('sigmoid')(fc)
      
  model = Model(inputs=[inputs], outputs=[outputs])
  model.summary()
  
  return model

# %% [markdown]
# ## 저장해둔 train, test set 불러오기

# %%
X_train, X_test, y_train, y_test = np.load(numpy_data, allow_pickle=True)

X_train = np.expand_dims(X_train, axis=-1)
X_test = np.expand_dims(X_test, axis =-1)

print(X_train.shape)
print(X_train.shape[0])
print(np.bincount(y_train))
print(np.bincount(y_test))
# Out:
# (1383, 128, 128, 1)
# 1383
# [502 881]
# [ 52 102]

# %%
# Check X_train data by plotting befor training

ix = random.randint(1, X_train.shape[0])
plt.imshow(X_train[ix].reshape((128, 128)))
if Y_train[ix] == 0:
  plt.title('normal')
elif Y_train[ix] == 1:
  plt.title('fracture')
plt.show()

# %%
# _, _, image_size, channels = X_train.shape
_, _, image_size, channels = X_train.shape
X_train = X_train.astype('float32') / 255.
X_test = X_test.astype('float32') / 255.
print(image_size, channels)
# Out:
# 128 1

# %% [markdown]
# ## 모델 컴파일

# %%
classifier = classifier_model(image_size, channels)
classifier.compile(loss='binary_crossentropy', optimizer=RMSprop(), metrics=['accuracy'])
# Out:
# Model: "model_29"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_29 (InputLayer)        (None, 128, 128, 1)       0
# _________________________________________________________________
# conv2d_225 (Conv2D)          (None, 128, 128, 8)       80
# _________________________________________________________________
# leaky_re_lu_253 (LeakyReLU)  (None, 128, 128, 8)       0
# _________________________________________________________________
# batch_normalization_225 (Bat (None, 128, 128, 8)       32
# _________________________________________________________________
# dropout_449 (Dropout)        (None, 128, 128, 8)       0
# _________________________________________________________________
# max_pooling2d_197 (MaxPoolin (None, 64, 64, 8)         0
# _________________________________________________________________
# dropout_450 (Dropout)        (None, 64, 64, 8)         0
# _________________________________________________________________
# conv2d_226 (Conv2D)          (None, 64, 64, 16)        1168
# _________________________________________________________________
# leaky_re_lu_254 (LeakyReLU)  (None, 64, 64, 16)        0
# _________________________________________________________________
# batch_normalization_226 (Bat (None, 64, 64, 16)        64
# _________________________________________________________________
# dropout_451 (Dropout)        (None, 64, 64, 16)        0
# _________________________________________________________________
# max_pooling2d_198 (MaxPoolin (None, 32, 32, 16)        0
# _________________________________________________________________
# dropout_452 (Dropout)        (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_227 (Conv2D)          (None, 32, 32, 32)        12832
# _________________________________________________________________
# leaky_re_lu_255 (LeakyReLU)  (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_227 (Bat (None, 32, 32, 32)        128
# _________________________________________________________________
# dropout_453 (Dropout)        (None, 32, 32, 32)        0
# _________________________________________________________________
# max_pooling2d_199 (MaxPoolin (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_454 (Dropout)        (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_228 (Conv2D)          (None, 16, 16, 64)        18496
# _________________________________________________________________
# leaky_re_lu_256 (LeakyReLU)  (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_228 (Bat (None, 16, 16, 64)        256
# _________________________________________________________________
# dropout_455 (Dropout)        (None, 16, 16, 64)        0
# _________________________________________________________________
# max_pooling2d_200 (MaxPoolin (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_456 (Dropout)        (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_229 (Conv2D)          (None, 8, 8, 128)         73856
# _________________________________________________________________
# leaky_re_lu_257 (LeakyReLU)  (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_229 (Bat (None, 8, 8, 128)         512
# _________________________________________________________________
# dropout_457 (Dropout)        (None, 8, 8, 128)         0
# _________________________________________________________________
# max_pooling2d_201 (MaxPoolin (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_458 (Dropout)        (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_230 (Conv2D)          (None, 4, 4, 256)         819456
# _________________________________________________________________
# leaky_re_lu_258 (LeakyReLU)  (None, 4, 4, 256)         0
# _________________________________________________________________
# batch_normalization_230 (Bat (None, 4, 4, 256)         1024
# _________________________________________________________________
# dropout_459 (Dropout)        (None, 4, 4, 256)         0
# _________________________________________________________________
# max_pooling2d_202 (MaxPoolin (None, 2, 2, 256)         0
# _________________________________________________________________
# dropout_460 (Dropout)        (None, 2, 2, 256)         0
# _________________________________________________________________
# conv2d_231 (Conv2D)          (None, 2, 2, 512)         2097664
# _________________________________________________________________
# leaky_re_lu_259 (LeakyReLU)  (None, 2, 2, 512)         0
# _________________________________________________________________
# batch_normalization_231 (Bat (None, 2, 2, 512)         2048
# _________________________________________________________________
# dropout_461 (Dropout)        (None, 2, 2, 512)         0
# _________________________________________________________________
# max_pooling2d_203 (MaxPoolin (None, 1, 1, 512)         0
# _________________________________________________________________
# dropout_462 (Dropout)        (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_232 (Conv2D)          (None, 1, 1, 512)         4194816
# _________________________________________________________________
# leaky_re_lu_260 (LeakyReLU)  (None, 1, 1, 512)         0
# _________________________________________________________________
# batch_normalization_232 (Bat (None, 1, 1, 512)         2048
# _________________________________________________________________
# dropout_463 (Dropout)        (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten_29 (Flatten)         (None, 512)               0
# _________________________________________________________________
# dense_57 (Dense)             (None, 1024)              525312
# _________________________________________________________________
# leaky_re_lu_261 (LeakyReLU)  (None, 1024)              0
# _________________________________________________________________
# dropout_464 (Dropout)        (None, 1024)              0
# _________________________________________________________________
# dense_58 (Dense)             (None, 1)                 1025
# _________________________________________________________________
# activation_29 (Activation)   (None, 1)                 0
# =================================================================
# Total params: 7,750,817
# Trainable params: 7,747,761
# Non-trainable params: 3,056
# _________________________________________________________________

# %% [markdown]
# ### Set ModelCheckpoint and EalryStopping

# %%
# model_dir = './whole/x-ray/classifier/model'
model_dir = './resize_reverse_crop_128/classifier/model' #20200515
makedirs(model_dir, exist_ok=True)

model_path = model_dir + "/classify_model_mixed_batchsize12_loss{val_loss:.2f}_acc{val_accuracy: .2f}.model"
# model_path = model_dir + "/fracture_normal_classify_model_batch_size20.model"
    
checkpoint = ModelCheckpoint(filepath=model_path, monitor='val_loss', verbose=1, save_best_only=True)
# checkpoint = ModelCheckpoint(filepath=model_path, monitor='accuracy', verbose=1, save_best_only=True)
# checkpoint = ModelCheckpoint(filepath=model_path, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)
# checkpoint = ModelCheckpoint(filepath=model_path, monitor='val_loss', verbose=1, save_best_only=False, mode='max')

early_stopping = EarlyStopping(monitor='val_loss', patience=30)

# %% [markdown]
# ## 모델 훈련

# %%
# history = classifier.fit(X_train, y_train, batch_size=12, epochs=300, validation_split=0.3, callbacks=[checkpoint]) ##########
history = classifier.fit(X_train, y_train, batch_size=12, epochs=100, validation_split=0.3, callbacks=[checkpoint, early_stopping])
# history = classifier.fit(X_train, y_train, batch_size=1, epochs=100, validation_split=0.15, callbacks=[checkpoint, early_stopping])
# Out:
# Train on 968 samples, validate on 415 samples
# Epoch 1/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.1118 - accuracy: 0.9742 - val_loss: 1.1864 - val_accuracy: 0.7301
#
# Epoch 00001: val_loss did not improve from 0.54368
# Epoch 2/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0775 - accuracy: 0.9824 - val_loss: 1.1884 - val_accuracy: 0.7470
#
# Epoch 00002: val_loss did not improve from 0.54368
# Epoch 3/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0792 - accuracy: 0.9793 - val_loss: 1.1074 - val_accuracy: 0.7687
#
# Epoch 00003: val_loss did not improve from 0.54368
# Epoch 4/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.1073 - accuracy: 0.9700 - val_loss: 0.7638 - val_accuracy: 0.8410
#
# Epoch 00004: val_loss did not improve from 0.54368
# Epoch 5/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0743 - accuracy: 0.9814 - val_loss: 1.4481 - val_accuracy: 0.6843
#
# Epoch 00005: val_loss did not improve from 0.54368
# Epoch 6/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0780 - accuracy: 0.9804 - val_loss: 1.1288 - val_accuracy: 0.7976
#
# Epoch 00006: val_loss did not improve from 0.54368
# Epoch 7/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0722 - accuracy: 0.9855 - val_loss: 1.0518 - val_accuracy: 0.7759
#
# Epoch 00007: val_loss did not improve from 0.54368
# Epoch 8/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0662 - accuracy: 0.9783 - val_loss: 0.9079 - val_accuracy: 0.8554
#
# Epoch 00008: val_loss did not improve from 0.54368
# Epoch 9/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0823 - accuracy: 0.9711 - val_loss: 1.1065 - val_accuracy: 0.7494
#
# Epoch 00009: val_loss did not improve from 0.54368
# Epoch 10/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0535 - accuracy: 0.9897 - val_loss: 0.8989 - val_accuracy: 0.8554
#
# Epoch 00010: val_loss did not improve from 0.54368
# Epoch 11/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0955 - accuracy: 0.9700 - val_loss: 0.8885 - val_accuracy: 0.8410
#
# Epoch 00011: val_loss did not improve from 0.54368
# Epoch 12/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0965 - accuracy: 0.9804 - val_loss: 0.8555 - val_accuracy: 0.7952
#
# Epoch 00012: val_loss did not improve from 0.54368
# Epoch 13/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0975 - accuracy: 0.9814 - val_loss: 1.0007 - val_accuracy: 0.7783
#
# Epoch 00013: val_loss did not improve from 0.54368
# Epoch 14/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0503 - accuracy: 0.9845 - val_loss: 1.1617 - val_accuracy: 0.7783
#
# Epoch 00014: val_loss did not improve from 0.54368
# Epoch 15/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0962 - accuracy: 0.9731 - val_loss: 1.5277 - val_accuracy: 0.6578
#
# Epoch 00015: val_loss did not improve from 0.54368
# Epoch 16/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0992 - accuracy: 0.9700 - val_loss: 0.9183 - val_accuracy: 0.7759
#
# Epoch 00016: val_loss did not improve from 0.54368
# Epoch 17/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0705 - accuracy: 0.9793 - val_loss: 1.1922 - val_accuracy: 0.7542
#
# Epoch 00017: val_loss did not improve from 0.54368
# Epoch 18/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0649 - accuracy: 0.9783 - val_loss: 1.5326 - val_accuracy: 0.7012
#
# Epoch 00018: val_loss did not improve from 0.54368
# Epoch 19/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0974 - accuracy: 0.9793 - val_loss: 0.8854 - val_accuracy: 0.8337
#
# Epoch 00019: val_loss did not improve from 0.54368
# Epoch 20/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0653 - accuracy: 0.9845 - val_loss: 0.7584 - val_accuracy: 0.8434
#
# Epoch 00020: val_loss did not improve from 0.54368
# Epoch 21/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0522 - accuracy: 0.9866 - val_loss: 1.0608 - val_accuracy: 0.7855
#
# Epoch 00021: val_loss did not improve from 0.54368
# Epoch 22/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0646 - accuracy: 0.9835 - val_loss: 0.9970 - val_accuracy: 0.8048
#
# Epoch 00022: val_loss did not improve from 0.54368
# Epoch 23/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0893 - accuracy: 0.9731 - val_loss: 1.1213 - val_accuracy: 0.7349
#
# Epoch 00023: val_loss did not improve from 0.54368
# Epoch 24/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0796 - accuracy: 0.9721 - val_loss: 0.8582 - val_accuracy: 0.8120
#
# Epoch 00024: val_loss did not improve from 0.54368
# Epoch 25/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0664 - accuracy: 0.9814 - val_loss: 0.9605 - val_accuracy: 0.8530
#
# Epoch 00025: val_loss did not improve from 0.54368
# Epoch 26/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0796 - accuracy: 0.9855 - val_loss: 1.0601 - val_accuracy: 0.8000
#
# Epoch 00026: val_loss did not improve from 0.54368
# Epoch 27/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0827 - accuracy: 0.9804 - val_loss: 1.0119 - val_accuracy: 0.8241
#
# Epoch 00027: val_loss did not improve from 0.54368
# Epoch 28/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0881 - accuracy: 0.9731 - val_loss: 0.8113 - val_accuracy: 0.8096
#
# Epoch 00028: val_loss did not improve from 0.54368
# Epoch 29/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0696 - accuracy: 0.9793 - val_loss: 1.0933 - val_accuracy: 0.7976
#
# Epoch 00029: val_loss did not improve from 0.54368
# Epoch 30/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0694 - accuracy: 0.9855 - val_loss: 1.3835 - val_accuracy: 0.7325
#
# Epoch 00030: val_loss did not improve from 0.54368
# Epoch 31/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0603 - accuracy: 0.9845 - val_loss: 1.0403 - val_accuracy: 0.8217
#
# Epoch 00031: val_loss did not improve from 0.54368
# Epoch 32/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0581 - accuracy: 0.9876 - val_loss: 0.9252 - val_accuracy: 0.8386
#
# Epoch 00032: val_loss did not improve from 0.54368
# Epoch 33/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0607 - accuracy: 0.9855 - val_loss: 1.0100 - val_accuracy: 0.8458
#
# Epoch 00033: val_loss did not improve from 0.54368
# Epoch 34/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0900 - accuracy: 0.9762 - val_loss: 0.6633 - val_accuracy: 0.8289
#
# Epoch 00034: val_loss did not improve from 0.54368
# Epoch 35/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0782 - accuracy: 0.9814 - val_loss: 1.1547 - val_accuracy: 0.7494
#
# Epoch 00035: val_loss did not improve from 0.54368
# Epoch 36/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0713 - accuracy: 0.9742 - val_loss: 0.9423 - val_accuracy: 0.8120
#
# Epoch 00036: val_loss did not improve from 0.54368
# Epoch 37/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0571 - accuracy: 0.9855 - val_loss: 1.1509 - val_accuracy: 0.8024
#
# Epoch 00037: val_loss did not improve from 0.54368
# Epoch 38/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0796 - accuracy: 0.9752 - val_loss: 0.9761 - val_accuracy: 0.8386
#
# Epoch 00038: val_loss did not improve from 0.54368
# Epoch 39/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0440 - accuracy: 0.9835 - val_loss: 1.0021 - val_accuracy: 0.8048
#
# Epoch 00039: val_loss did not improve from 0.54368
# Epoch 40/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0325 - accuracy: 0.9907 - val_loss: 1.4239 - val_accuracy: 0.8000
#
# Epoch 00040: val_loss did not improve from 0.54368
# Epoch 41/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0441 - accuracy: 0.9855 - val_loss: 1.6513 - val_accuracy: 0.7446
#
# Epoch 00041: val_loss did not improve from 0.54368
# Epoch 42/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0544 - accuracy: 0.9917 - val_loss: 2.1969 - val_accuracy: 0.6819
#
# Epoch 00042: val_loss did not improve from 0.54368
# Epoch 43/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0777 - accuracy: 0.9824 - val_loss: 1.0920 - val_accuracy: 0.7807
#
# Epoch 00043: val_loss did not improve from 0.54368
# Epoch 44/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0493 - accuracy: 0.9855 - val_loss: 2.7756 - val_accuracy: 0.5952
#
# Epoch 00044: val_loss did not improve from 0.54368
# Epoch 45/100
# 968/968 [==============================] - 2s 2ms/step - loss: 0.0628 - accuracy: 0.9845 - val_loss: 1.0227 - val_accuracy: 0.8410
#
# Epoch 00045: val_loss did not improve from 0.54368
# Epoch 46/100
# 936/968 [============================>.] - ETA: 0s - loss: 0.0522 - accuracy: 0.9861
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-100-cea2cbd69437> in <module>()
#       1 # history = classifier.fit(X_train, y_train, batch_size=12, epochs=300, validation_split=0.3, callbacks=[checkpoint]) ##########
# ----> 2 history = classifier.fit(X_train, y_train, batch_size=12, epochs=100, validation_split=0.3, callbacks=[checkpoint, early_stopping])
#       3 # history = classifier.fit(X_train, y_train, batch_size=1, epochs=100, validation_split=0.15, callbacks=[checkpoint, early_stopping])
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     208                                          batch_size=batch_size,
#     209                                          callbacks=callbacks,
# --> 210                                          verbose=0)
#     211                     val_outs = to_list(val_outs)
#     212                     # Same labels assumed.
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_arrays.py in test_loop(model, f, ins, batch_size, verbose, steps, callbacks)
#     447             batch_logs = {'batch': batch_index, 'size': len(batch_ids)}
#     448             callbacks._call_batch_hook('test', 'begin', batch_index, batch_logs)
# --> 449             batch_outs = f(ins_batch)
#     450             if isinstance(batch_outs, list):
#     451                 if batch_index == 0:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    3790         value = math_ops.cast(value, tensor.dtype)
#    3791       converted_inputs.append(value)
# -> 3792     outputs = self._graph_fn(*converted_inputs)
#    3793
#    3794     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    1603       TypeError: For invalid positional/keyword argument combinations.
#    1604     """
# -> 1605     return self._call_impl(args, kwargs)
#    1606
#    1607   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1643       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1644           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1645     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1646
#    1647   def _filtered_call(self, args, kwargs):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1744       # No tape is watching; skip to running the function.
#    1745       return self._build_call_outputs(self._inference_function.call(
# -> 1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#    1748         args,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596               inputs=args,
#     597               attrs=attrs,
# --> 598               ctx=ctx)
#     599         else:
#     600           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Accuracy

# %%
print("정확도 : %.2f " %(classifier.evaluate(X_test, y_test)[1]))
# Out:
# 154/154 [==============================] - 0s 292us/step
# 정확도 : 0.82

# %% [markdown]
# ### 그래프: loss, accuracy

# %%
# import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
# plt.plot(history.history['acc'])
plt.plot(history.history['accuracy'])
# plt.plot(history.history['val_acc'])
plt.plot(history.history['val_accuracy'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss', 'val_loss', 'accuracy', 'val_accuracy'], loc='upper left')
plt.show()

# %% [markdown]
# ## Classifier model 검증하기 (Test directory)

# %%
# from PIL import Image
# import os, glob, random, numpy as np
# from keras.models import load_model
# import tensorflow as tf
# import matplotlib.pyplot as plt
# from matplotlib.image import imread

seed = 5
# tf.set_random_seed(seed)
np.random.seed(seed)

caltech_dir = './resize_reverse_crop_128/classifier/images/test' #20200515


# img_w = 224
img_w = 128 #20200515
# img_h = 224
img_h = 128 #20200515
# channel = 3
channel = 1

pixels = img_h * img_w * channel

X = []
filenames = []
files = glob.glob(caltech_dir + "/*/*.*")
for i, f in enumerate(files):
    img = Image.open(f).convert('L') #20200515
    # img = img.convert('RGB')
    img = img.resize((img_w, img_h))
    data = np.asarray(img)

    filenames.append(f)
    X.append(data)

X = np.array(X)
print(X.shape)

ix = random.randint(1, X.shape[0])
plt.imshow(X[ix])
plt.show()
# Out:
# (365, 128, 128)

# %%
X = np.expand_dims(X, axis=-1)
X = X.astype(float) / 255

# %% [markdown]
# ### prediction and result

# %%
# model = load_model('./whole/x-ray/classifier/model/fracture_normal_classify.model')
# model = load_model('./whole/x-ray/classifier/model/fracture_normal_classify_model.model')
model = load_model('./resize_reverse_crop_128/classifier/model/classify_model_batchsize12_loss0.39_acc 0.87.model') #20200515
prediction = model.predict(X)

np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})

cnt = 0
for i in prediction:
    if i >= 0.5:
      print("해당 " + filenames[cnt].split("/")[-2] + ' ' + filenames[cnt].split("/")[-1] + "  이미지는 1: 골절 로 추정됩니다.")
    else :
      print("해당 " + filenames[cnt].split("/")[-2] + ' ' + filenames[cnt].split("/")[-1] + "  이미지는 0: 비골절 로 추정됩니다.")
    cnt += 1
# Out:
# 해당 fracture 1030r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1036l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1038l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1043l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1043r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1047r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1054l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1056l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1057r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1064r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 1066r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1071l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1071r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1074l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1082l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 1086r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1088l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1093r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1094r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 1099l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1099r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 109l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 10r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1101l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1101r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 1103r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 1106r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1108l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1108r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1112r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1113l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1113r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1114r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1124r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1130l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1132l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1134l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 113l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 113r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1144l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1152r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1153l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1159r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 115r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1160l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1160r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1166r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1171l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1172l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1172r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1173r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1175r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1176l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1177r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1180r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 1181r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1185l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1189l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1192l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 1205r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1230l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1232l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1234l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1234r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 123r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1242l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1245l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1251r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1260l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1262l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 126l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 1270l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1272l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1293l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1298l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 129l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 129r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1304l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1318r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1319l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1320r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1331r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1339l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1345r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 1346r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1351l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1364r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1365r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1368l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 136r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1373r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1375l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1379l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 1400l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1407l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1415l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1422r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1432l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1449r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 145r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1494r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 1499r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 150r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 159r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 164l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 16l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 180l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 184r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 185r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 193l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 193r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 199r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 200l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 200r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 201l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 203l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 207r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 208r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 210r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 216l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 220l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 221l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 221r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 223r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 225l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 227l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 227r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 228r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 229r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 22l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 22r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 236l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 23r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 241l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 247l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 250l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 250r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 255l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 257r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 259r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 25r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 261r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 263l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 266l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 276r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 281l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 282r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 286l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 294l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 297l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 302l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 311l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 311r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 314r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 316l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 316r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 318l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 320l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 320r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 322l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 324l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 33l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 343r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 345l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 345r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 357r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 370l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 371r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 373l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 383r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 384l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 385r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 389l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 393l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 396l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 400l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 403r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 407r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 419r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 427r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 428l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 430l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 436l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 438l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 442r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 443l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 444l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 447l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 449l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 449r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 450l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 453r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 454r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 456r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 457l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 458l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 459r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 460l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 460r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 475r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 476r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 482l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 486l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 487r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 488r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 491l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 493l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 496l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 56l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 57r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 58r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 5l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 5r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 69l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 79l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 86r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 92l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 93r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 fracture 97r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 99r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 fracture 9r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 1058l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1118l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1119l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1119r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1126l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1126r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1240l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1246l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1250r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 1257r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1281l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1296l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1333r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1353r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1366l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1374l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1374r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1376r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1378l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1386l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1394l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1398l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1404r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1406r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1429r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1446r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1450r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 1453r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1458r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1460l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1460r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1486r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1487r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1489l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 1501l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1504l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1507r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1509l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1512r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 1516r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1517l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1518r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1532l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1543r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1544r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1554l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1554r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1556r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 1558l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1561r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1562l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 1566l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 1566r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1568l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 1579r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1582r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1584r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1586r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1590r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1592l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 1592r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1593r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1596r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1597l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1603r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1606r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1610r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1611r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1612r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 1618r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1621l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1625l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1625r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1626l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1630r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1649l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1657l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1659l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1663l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1663r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1666l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1670r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1675r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1676l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1680l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1683r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1686l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1691r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1692r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1698r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1701l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1704r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1705l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 1705r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1709r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 1710l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1711r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1712l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1720l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1720r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1723r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1724r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1726l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1727l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1727r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1730l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1731r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1735r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1736r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1743r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1744l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1750l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1750r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1751l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1753l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1754r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1755l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1757l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1761r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1762l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1764l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1769l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1770l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1775l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1776r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1777l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1777r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 1779l.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 179r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 197l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 20l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 235r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 256r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 262r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 272r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 285l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 285r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 295l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 295r.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 339r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 340l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 360r.jpg  이미지는 0: 비골절 로 추정됩니다.
# 해당 normal 365l.jpg  이미지는 1: 골절 로 추정됩니다.
# 해당 normal 51l.jpg  이미지는 0: 비골절 로 추정됩니다.

# %%
# print(prediction)

# %%
# import matplotlib.pyplot as plt
plt.hist(prediction, bins=50)
plt.show()

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

cnt = 0

TF = []
FF = []
TN = []
FN = []
for i in prediction:
  if i >= 0.5:
    if filenames[cnt].split("/")[-2] == 'fracture':
      TF.append(i)
    elif filenames[cnt].split("/")[-2] == 'normal':
      FF.append(i)
  else:
    if filenames[cnt].split("/")[-2] == 'normal':
      TN.append(i)
    elif filenames[cnt].split("/")[-2] == 'fracture':
      FN.append(i)
  cnt += 1



df = pd.DataFrame({'cross result':['True Fracture', 'False Fracture', 'True Normal', 'False Normal'], 'count':[len(TF), len(FF), len(TN), len(FN)]})
ax = df.plot.bar(x='cross result', y='count', rot=0)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
plt.show()
